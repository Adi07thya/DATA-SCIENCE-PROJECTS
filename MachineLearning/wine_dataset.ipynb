# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("winequality-red.csv",delimiter=';')

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## finding the Zscore to remove outliers

# %%
from scipy import stats
import numpy as np
z=np.abs(stats.zscore(df))
z
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df_new.skew()
# Out:
# fixed acidity           0.823934
# volatile acidity        0.380659
# citric acid             0.291297
# residual sugar          2.456107
# chlorides               2.275162
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# density                 0.055738
# pH                      0.114705
# sulphates               0.891492
# alcohol                 0.758958
# quality                 0.407865
# dtype: float64

# %%
x=[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'quality']]
y=df[['alcohol']]

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,4,1)
plt.plot(df['fixed acidity'],y)
plt.subplot(3,4,2)
plt.plot(df['volatile acidity'],y)
plt.subplot(3,4,3)
plt.plot(df['citric acid'],y)
plt.subplot(3,4,4)
plt.plot(df['fixed acidity'],y)
plt.subplot(3,4,5)
plt.plot(df['residual sugar'],y)
plt.subplot(3,4,6)
plt.plot(df['chlorides'],y)
plt.subplot(3,4,7)
plt.plot(df['free sulfur dioxide'],y)
plt.subplot(3,4,8)
plt.plot(df['fixed acidity'],y)
plt.subplot(3,4,9)
plt.plot(df[ 'total sulfur dioxide'],y)
plt.subplot(3,4,10)
plt.plot(df['density'],y)
plt.subplot(3,4,11)
plt.plot(df['pH'],y)
plt.subplot(3,4,12)
plt.plot(df['sulphates'],y)
plt.show()

# %%
df['sulphates'].describe()
# Out:
# count    1599.000000
# mean        0.658149
# std         0.169507
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
df['residual sugar']=np.where(df['residual sugar']>= 2.600000,  2.600000,df['residual sugar'])

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar         -0.408897
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
df['chlorides']=np.where(df['chlorides']>= 0.090000,   0.090000,df['chlorides'])

# %%
df['sulphates']=np.where(df['sulphates']>=  0.730000, 0.730000,df['sulphates'])

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar         -0.408897
# chlorides              -1.001658
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates              -0.304100
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_new.corr(),annot=True)
plt.show()

# %%
sns.regplot(df_new['chlorides'],df_new['sulphates'],data=df_new)
plt.ylim(0,)
# Out:
# (0, 1.2025727471767205)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.090
# 2               7.8             0.760         0.04             2.3      0.090
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             2.6      0.071
# 10              6.7             0.580         0.08             1.8      0.090
# ...

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar         -0.408897
# chlorides              -1.001658
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates              -0.304100
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## Training the model

# %%
x=df.drop('quality',1)
y=df['quality']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.preprocessing import MinMaxScaler
gb=GaussianNB()
br=BernoulliNB()
mt=MultinomialNB()
input=[['scale',MinMaxScaler()],['mode',mt]]
print(input)
pipe=Pipeline(input)
res=pipe.fit(np.abs(X_train),Y_train)

yhat=res.predict((X_train))
print(yhat)
print(accuracy_score(Y_train,yhat))
print(classification_report(Y_train,yhat))
# Out:
# [['scale', MinMaxScaler(copy=True, feature_range=(0, 1))], ['mode', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)]]
# [5 5 5 ... 5 6 5]
# 0.5817694369973191
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00        34
#            5       0.62      0.81      0.70       473
#            6       0.53      0.58      0.56       458
#            7       0.00      0.00      0.00       136
#            8       0.00      0.00      0.00        13
#
#     accuracy                           0.58      1119
#    macro avg       0.19      0.23      0.21      1119
# weighted avg       0.48      0.58      0.53      1119
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
df['final quality']=df['quality'].apply(lambda x:'low' if(x<=5) else ('medium' if (x==6) else( 'High' )))

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.090
# 2               7.8             0.760         0.04             2.3      0.090
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             2.6      0.071
# 10              6.7             0.580         0.08             1.8      0.090
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'final quality'],
#       dtype='object')

# %%
df['final quality'].value_counts()
# Out:
# low       744
# medium    638
# High      217
# Name: final quality, dtype: int64

# %%
df1=df.drop('quality',1)
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.090
# 2               7.8             0.760         0.04             2.3      0.090
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             2.6      0.071
# 10              6.7             0.580         0.08             1.8      0.090
# ...

# %%
x1=df1.drop('final quality',1)
y1=df1['final quality']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x1,y1,test_size=0.3,random_state=101)

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.preprocessing import MinMaxScaler
gb=GaussianNB()
br=BernoulliNB()
mt=MultinomialNB()
input=[['scale',MinMaxScaler()],['mode',mt]]
print(input)
pipe=Pipeline(input)
res=pipe.fit(np.abs(X_train),Y_train)

yhat=res.predict((X_train))
print(yhat)
print(accuracy_score(Y_train,yhat))
print(classification_report(Y_train,yhat))
# Out:
# [['scale', MinMaxScaler(copy=True, feature_range=(0, 1))], ['mode', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)]]
# ['low' 'low' 'low' ... 'low' 'medium' 'low']
# 0.5513851653261841
#               precision    recall  f1-score   support
#
#         High       0.00      0.00      0.00       149
#          low       0.58      0.93      0.71       512
#       medium       0.48      0.30      0.37       458
#
#     accuracy                           0.55      1119
#    macro avg       0.35      0.41      0.36      1119
# weighted avg       0.46      0.55      0.48      1119
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

# %%
from sklearn.preprocessing import MinMaxScaler
svc=SV(C=1,kernel='rbf',gamma=1,degree=1)
input=[['scale',MinMaxScaler()],['mode',svc]]
print(input)
pipe=Pipeline(input)
res=pipe.fit(X_train,Y_train)
# Out:
# [['scale', MinMaxScaler(copy=True, feature_range=(0, 1))], ['mode', SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=1, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)]]

# %%
from sklearn.preprocessing import MinMaxScaler
svc=SVC(C=10,kernel='linear',gamma=0.001,degree=1)
input=[['scale',MinMaxScaler()],['mode',svc]]
print(input)
pipe=Pipeline(input)
res=pipe.fit(X_train,Y_train)

yhat=res.predict((X_train))
print(yhat)
print(accuracy_score(Y_train,yhat))
print(classification_report(Y_train,yhat))
# Out:
# [['scale', MinMaxScaler(copy=True, feature_range=(0, 1))], ['mode', SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=1, gamma=0.001, kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)]]
# ['medium' 'medium' 'low' ... 'low' 'medium' 'low']
# 0.6630920464700626
#               precision    recall  f1-score   support
#
#         High       0.68      0.46      0.55       149
#          low       0.72      0.77      0.74       512
#       medium       0.60      0.61      0.60       458
#
#     accuracy                           0.66      1119
#    macro avg       0.67      0.61      0.63      1119
# weighted avg       0.66      0.66      0.66      1119
